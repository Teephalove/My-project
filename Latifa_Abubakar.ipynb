# %% [markdown]
# <a href="https://colab.research.google.com/github/Teephalove/My-project/blob/main/Latifa_Abubakar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TASK 2
# Conduct an initial examination of the data, including identifying the types of data, calculating statistics, focusing on certain aspects, and determining the distribution of variables. The goal of this initial step is to gain a comprehensive understanding of the dataset.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#@title
#importing libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize']=15,8

# %%
#@title
#Read the client dataset, first 5 rows
data=pd.read_csv('client_data.csv')
data.head()
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
#@title
#the last five rows of the client data
data.tail()
# Out:
#                                      id                     channel_sales  \
# 14601  18463073fb097fc0ac5d3e040f356987  foosdfpfkusacimwkcsosbicdxkicaua
# 14602  d0a6f71671571ed83b2645d23af6de00  foosdfpfkusacimwkcsosbicdxkicaua
# 14603  10e6828ddd62cbcf687cb74928c4c2d2  foosdfpfkusacimwkcsosbicdxkicaua
# 14604  1cf20fd6206d7678d5bcafd28c53b4db  foosdfpfkusacimwkcsosbicdxkicaua
# 14605  563dde550fd624d7352f3de77c0cdfcd                           MISSING
#
#        cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 14601     32270         47940                0  2012-05-24  2016-05-08
# 14602      7223             0              181  2012-08-27  2016-08-27
# 14603      1844             0              179  2012-02-08  2016-02-07
# 14604       131             0                0  2012-08-30  2016-08-30
# 14605      8730             0                0  2009-12-18  2016-12-17
#
#       date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
#@title
#read the price dataset
data_price=pd.read_csv('price_data.csv')
data_price.head()
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %%
#@title
#tail of the price dataset
data_price.tail()
# Out:
#                                       id  price_date  price_off_peak_var  \
# 192997  16f51cdc2baa19af0b940ee1b3dd17d5  2015-08-01            0.119916
# 192998  16f51cdc2baa19af0b940ee1b3dd17d5  2015-09-01            0.119916
# 192999  16f51cdc2baa19af0b940ee1b3dd17d5  2015-10-01            0.119916
# 193000  16f51cdc2baa19af0b940ee1b3dd17d5  2015-11-01            0.119916
# 193001  16f51cdc2baa19af0b940ee1b3dd17d5  2015-12-01            0.119916
#
#         price_peak_var  price_mid_peak_var  price_off_peak_fix  \
# 192997        0.102232            0.076257           40.728885
# 192998        0.102232            0.076257           40.728885
# 192999        0.102232            0.076257           40.728885
# 193000        0.102232            0.076257           40.728885
# 193001        0.102232            0.076257           40.728885
#
#         price_peak_fix  price_mid_peak_fix
# 192997        24.43733           16.291555
# 192998        24.43733           16.291555
# ...

# %%
#@title
#info of the client data
data.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Columns: 26 entries, id to churn
# dtypes: float64(11), int64(7), object(8)
# memory usage: 2.9+ MB

# %%
#the number of rows and columns in the client data
data.shape
# Out:
# (14606, 26)

# %%
#info about the price data
data_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %%
#The number of rows and columns
data_price.shape
# Out:
# (193002, 8)

# %% [markdown]
# The datasets are in two forms, client and price. The client has 14606 and 26 columns. The second dataset has 193002 rows and 8 columns. The dataset is very clean with no null values. this data is subjected for further analysis

# %% [markdown]
# ### DATA CLEANING

# %%
#checking the names of columns
data.columns
# Out:
# Index(['id', 'channel_sales', 'cons_12m', 'cons_gas_12m', 'cons_last_month',
#        'date_activ', 'date_end', 'date_modif_prod', 'date_renewal',
#        'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
#        'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
#        'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'has_gas',
#        'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
#        'net_margin', 'num_years_antig', 'origin_up', 'pow_max', 'churn'],
#       dtype='object')

# %%
#checking the various columns
data_price.columns
# Out:
# Index(['id', 'price_date', 'price_off_peak_var', 'price_peak_var',
#        'price_mid_peak_var', 'price_off_peak_fix', 'price_peak_fix',
#        'price_mid_peak_fix'],
#       dtype='object')

# %%
#checking the data types
data.dtypes
# Out:
# id                                 object
# channel_sales                      object
# cons_12m                            int64
# cons_gas_12m                        int64
# cons_last_month                     int64
# date_activ                         object
# date_end                           object
# date_modif_prod                    object
# date_renewal                       object
# forecast_cons_12m                 float64
# forecast_cons_year                  int64
# forecast_discount_energy          float64
# forecast_meter_rent_12m           float64
# forecast_price_energy_off_peak    float64
# forecast_price_energy_peak        float64
# forecast_price_pow_off_peak       float64
# has_gas                            object
# imp_cons                          float64
# margin_gross_pow_ele              float64
# margin_net_pow_ele                float64
# nb_prod_act                         int64
# net_margin                        float64
# ...

# %%
#the data types
data_price.dtypes
# Out:
# id                     object
# price_date             object
# price_off_peak_var    float64
# price_peak_var        float64
# price_mid_peak_var    float64
# price_off_peak_fix    float64
# price_peak_fix        float64
# price_mid_peak_fix    float64
# dtype: object

# %%
#checking the null values
data.isnull().sum()
# Out:
# id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# nb_prod_act                       0
# net_margin                        0
# num_years_antig                   0
# origin_up                         0
# pow_max                           0
# churn                             0
# ...

# %%
#checking null values
data_price.isnull().sum()
# Out:
# id                    0
# price_date            0
# price_off_peak_var    0
# price_peak_var        0
# price_mid_peak_var    0
# price_off_peak_fix    0
# price_peak_fix        0
# price_mid_peak_fix    0
# dtype: int64

# %%
#ensuring no duplicates
data.drop_duplicates()
# Out:
#                                      id                     channel_sales  \
# 0      24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1      d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2      764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3      bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4      149d57cf92fc41cf94415803a877cb4b                           MISSING
# ...                                 ...                               ...
# 14601  18463073fb097fc0ac5d3e040f356987  foosdfpfkusacimwkcsosbicdxkicaua
# 14602  d0a6f71671571ed83b2645d23af6de00  foosdfpfkusacimwkcsosbicdxkicaua
# 14603  10e6828ddd62cbcf687cb74928c4c2d2  foosdfpfkusacimwkcsosbicdxkicaua
# 14604  1cf20fd6206d7678d5bcafd28c53b4db  foosdfpfkusacimwkcsosbicdxkicaua
# 14605  563dde550fd624d7352f3de77c0cdfcd                           MISSING
#
#        cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# ...

# %%
#drpping null values
data_price.drop_duplicates()
# Out:
#                                       id  price_date  price_off_peak_var  \
# 0       038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1       038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2       038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3       038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4       038af19179925da21a25619c5a24b745  2015-05-01            0.149626
# ...                                  ...         ...                 ...
# 192997  16f51cdc2baa19af0b940ee1b3dd17d5  2015-08-01            0.119916
# 192998  16f51cdc2baa19af0b940ee1b3dd17d5  2015-09-01            0.119916
# 192999  16f51cdc2baa19af0b940ee1b3dd17d5  2015-10-01            0.119916
# 193000  16f51cdc2baa19af0b940ee1b3dd17d5  2015-11-01            0.119916
# 193001  16f51cdc2baa19af0b940ee1b3dd17d5  2015-12-01            0.119916
#
#         price_peak_var  price_mid_peak_var  price_off_peak_fix  \
# ...

# %%
#merging both datsets
New_data=pd.merge(data,data_price)
New_data
# Out:
#                                       id                     channel_sales  \
# 0       24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1       24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 2       24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 3       24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 4       24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# ...                                  ...                               ...
# 175144  563dde550fd624d7352f3de77c0cdfcd                           MISSING
# 175145  563dde550fd624d7352f3de77c0cdfcd                           MISSING
# 175146  563dde550fd624d7352f3de77c0cdfcd                           MISSING
# 175147  563dde550fd624d7352f3de77c0cdfcd                           MISSING
# 175148  563dde550fd624d7352f3de77c0cdfcd                           MISSING
#
# ...

# %%
New_data.shape
# Out:
# (175149, 33)

# %%
#getting info about the merged  data
New_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175149 entries, 0 to 175148
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              175149 non-null  object
#  1   channel_sales                   175149 non-null  object
#  2   cons_12m                        175149 non-null  int64
#  3   cons_gas_12m                    175149 non-null  int64
#  4   cons_last_month                 175149 non-null  int64
#  5   date_activ                      175149 non-null  object
#  6   date_end                        175149 non-null  object
#  7   date_modif_prod                 175149 non-null  object
#  8   date_renewal                    175149 non-null  object
#  9   forecast_cons_12m               175149 non-null  float64
#  10  forecast_cons_year              175149 non-null  int64
#  11  forecast_discount_energy        175149 non-null  float64
# ...

# %%
#dropping duplicates
New_data.drop_duplicates()
# Out:
#                                       id                     channel_sales  \
# 0       24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1       24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 2       24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 3       24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 4       24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# ...                                  ...                               ...
# 175144  563dde550fd624d7352f3de77c0cdfcd                           MISSING
# 175145  563dde550fd624d7352f3de77c0cdfcd                           MISSING
# 175146  563dde550fd624d7352f3de77c0cdfcd                           MISSING
# 175147  563dde550fd624d7352f3de77c0cdfcd                           MISSING
# 175148  563dde550fd624d7352f3de77c0cdfcd                           MISSING
#
# ...

# %% [markdown]
# ### STATISTICS OF THE DATA AND VISUALIZATION

# %%
#obtaining statistical data about the data
New_data.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.751490e+05  1.751490e+05    175149.000000      175149.000000
# mean   1.592606e+05  2.808072e+04     16095.518404        1868.343884
# std    5.735413e+05  1.629400e+05     64376.741908        2387.560169
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674000e+03  0.000000e+00         0.000000         494.980000
# 50%    1.411500e+04  0.000000e+00       792.000000        1112.610000
# 75%    4.076300e+04  0.000000e+00      3383.000000        2400.350000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count       175149.000000             175149.000000            175149.000000
# mean          1399.782380                  0.967028                63.074649
# std           3248.331276                  5.109025                66.143996
# ...

# %%
#Obtaining statistical data for the object data
New_data.describe(include=object)
# Out:
#                                       id                     channel_sales  \
# count                             175149                            175149
# unique                             14606                                 8
# top     24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# freq                                  12                             80971
#
#         date_activ    date_end date_modif_prod date_renewal has_gas  \
# count       175149      175149          175149       175149  175149
# unique        1796         368            2129          386       2
# top     2009-08-01  2016-02-01      2015-11-01   2015-06-23       f
# freq          1140        1740            8640         7039  143364
#
#                                origin_up  price_date
# count                             175149      175149
# unique                                 6          12
# top     lxidpiddsbxsbosboudacockeimpuepw  2015-08-01
# ...

# %%
#doing a correlation
corr=New_data.corr()
corr
# Out:
# <ipython-input-31-74c7e4151aa7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=New_data.corr()
#                                 cons_12m  cons_gas_12m  cons_last_month  \
# cons_12m                        1.000000      0.488253         0.968209
# cons_gas_12m                    0.488253      1.000000         0.506883
# cons_last_month                 0.968209      0.506883         1.000000
# forecast_cons_12m               0.194080      0.084520         0.177888
# forecast_cons_year              0.167141      0.081010         0.193613
# forecast_discount_energy       -0.043291     -0.012581        -0.040883
# forecast_meter_rent_12m         0.065275      0.041314         0.057491
# forecast_price_energy_off_peak -0.007696     -0.017550        -0.005150
# ...

# %%
#visualizing the correlation
sns.heatmap(corr)
plt.show()

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:

        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
             )

def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distirbution in a stacked histogram of churned or retained company
    """
    # Create a temporal dataframe with the data to be plot
    temp = pd.DataFrame({"Retention": dataframe[dataframe["churn"]==0][column],
    "Churn":dataframe[dataframe["churn"]==1][column]})
    # Plot the histogram
    temp[["Retention","Churn"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    # X-axis label
    ax.set_xlabel(column)
    # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %%
churn = New_data[['id', 'churn']]
churn.columns = ['Companies', 'churn']
churn_total = churn.groupby(churn['churn']).count()

churn_percentage = churn_total / churn_total.sum() * 100
plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5), legend_="lower right")

# %%
consumption = New_data[['id', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'imp_cons', 'has_gas', 'churn']]

fig, axs = plt.subplots(nrows=1, figsize=(18, 5))

plot_distribution(consumption, 'cons_12m', axs)

# %%
for i in consumption.columns[1:5]:
    fig, axs = plt.subplots(nrows=1, figsize=(18, 5))
    plot_distribution(consumption, i, axs)

# %%
price = New_data[['churn','price_off_peak_var','price_peak_var','price_mid_peak_var','price_off_peak_fix','price_peak_fix','price_mid_peak_fix']]

fig, axs = plt.subplots(nrows=1, figsize=(18, 5))

plot_distribution(price, 'price_off_peak_var', axs)

# %%
for i in price.columns[2:]:
    fig, axs = plt.subplots(nrows=1, figsize=(18, 5))
    plot_distribution(price, i, axs)

# %%
id_churn=New_data[['id','churn']]
id_churn
# Out:
#                                       id  churn
# 0       24011ae4ebbe3035111d65fa7c15bc57      1
# 1       24011ae4ebbe3035111d65fa7c15bc57      1
# 2       24011ae4ebbe3035111d65fa7c15bc57      1
# 3       24011ae4ebbe3035111d65fa7c15bc57      1
# 4       24011ae4ebbe3035111d65fa7c15bc57      1
# ...                                  ...    ...
# 175144  563dde550fd624d7352f3de77c0cdfcd      0
# 175145  563dde550fd624d7352f3de77c0cdfcd      0
# 175146  563dde550fd624d7352f3de77c0cdfcd      0
# 175147  563dde550fd624d7352f3de77c0cdfcd      0
# 175148  563dde550fd624d7352f3de77c0cdfcd      0
#
# [175149 rows x 2 columns]

# %%
group=id_churn.groupby('churn').id.sum()
group
# Out:
# churn
# 0    d29c2c54acc38ff3c0614d0a653813ddd29c2c54acc38f...
# 1    24011ae4ebbe3035111d65fa7c15bc5724011ae4ebbe30...
# Name: id, dtype: object

# %%
#@title
#obtaining the unique values in the channel sales column
New_data['channel_sales'].unique()
# Out:
# array(['foosdfpfkusacimwkcsosbicdxkicaua', 'MISSING',
#        'lmkebamcaaclubfxadlmueccxoimlema',
#        'usilxuppasemubllopkaafesmlibmsdf',
#        'ewpakwlliwisiwduibdlfmalxowmwpci',
#        'epumfxlbckeskwekxbiuasklxalciiuu',
#        'sddiedcslfslkckwlfkdpoeeailfpeds',
#        'fixdbufsefwooaasfcxdxadsiekoceaa'], dtype=object)

# %%
New_data['channel_sales'].value_counts()
# Out:
# foosdfpfkusacimwkcsosbicdxkicaua    80971
# MISSING                             44684
# lmkebamcaaclubfxadlmueccxoimlema    22105
# usilxuppasemubllopkaafesmlibmsdf    16486
# ewpakwlliwisiwduibdlfmalxowmwpci    10712
# sddiedcslfslkckwlfkdpoeeailfpeds      131
# epumfxlbckeskwekxbiuasklxalciiuu       36
# fixdbufsefwooaasfcxdxadsiekoceaa       24
# Name: channel_sales, dtype: int64

# %%
data_channel=pd.DataFrame(New_data['channel_sales'])
data_channel
# Out:
#                            channel_sales
# 0       foosdfpfkusacimwkcsosbicdxkicaua
# 1       foosdfpfkusacimwkcsosbicdxkicaua
# 2       foosdfpfkusacimwkcsosbicdxkicaua
# 3       foosdfpfkusacimwkcsosbicdxkicaua
# 4       foosdfpfkusacimwkcsosbicdxkicaua
# ...                                  ...
# 175144                           MISSING
# 175145                           MISSING
# 175146                           MISSING
# 175147                           MISSING
# 175148                           MISSING
#
# [175149 rows x 1 columns]

# %%
from pandas.io.formats.style_render import DataFrame
sales=data_channel.value_counts()
sales= pd.DataFrame(sales)
sales.columns=['Sales counts']
sales
# Out:
#                                   Sales counts
# channel_sales
# foosdfpfkusacimwkcsosbicdxkicaua         80971
# MISSING                                  44684
# lmkebamcaaclubfxadlmueccxoimlema         22105
# usilxuppasemubllopkaafesmlibmsdf         16486
# ewpakwlliwisiwduibdlfmalxowmwpci         10712
# sddiedcslfslkckwlfkdpoeeailfpeds           131
# epumfxlbckeskwekxbiuasklxalciiuu            36
# fixdbufsefwooaasfcxdxadsiekoceaa            24

# %%
#visualizing the count of the sale channel
sales.plot(kind='barh')
plt.show()

# %%
data_churn=pd.DataFrame(New_data['churn'])
data_churn
# Out:
#         churn
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 175144      0
# 175145      0
# 175146      0
# 175147      0
# 175148      0
#
# [175149 rows x 1 columns]

# %%
from pandas.io.formats.style_render import DataFrame
churns=data_churn.value_counts()
sales= pd.DataFrame(churns)
churns.columns=['Churn counts']
churns
# Out:
# churn
# 0        158146
# 1         17003
# dtype: int64

# %%
churns.plot(kind='barh')
plt.show()

# %% [markdown]
# The above visualization shows that a churn rettention is smaller than no churn. this can subject the data set to imbalance sampling and should be considered when creating a model

# %%
sns.regplot(data=New_data,x='price_off_peak_var',y='churn')
plt.show()

# %%
sns.regplot(data=New_data,x='price_peak_var',y='churn')
plt.show()

# %%
sns.regplot(data=New_data,x='price_mid_peak_var',y='churn')
plt.show()

# %% [markdown]
# ### HYPOTHESIS TEST

# %%
# !pip install scipy

# %%
import scipy.stats as stats
import math

# %%
pearson_coef, p_value = stats.pearsonr(New_data['price_mid_peak_var'], New_data['churn'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.04612014631531032  with a P-value of P = 4.274866195323846e-83

# %% [markdown]
# Conclusion:
#
# Since the p-value is  > 0.001, the correlation between price_mid_peak_var and churn is statistically insignificant, and the linear relationship isn't extremely strong (~0.046).

# %%
df_gptest = New_data[['churn','price_off_peak_var','price_peak_var','price_mid_peak_var','price_off_peak_fix','price_peak_fix','price_mid_peak_fix']]
grouped_test1 = df_gptest.groupby(['churn'],as_index=False).mean()
grouped_test1
# Out:
#    churn  price_off_peak_var  price_peak_var  price_mid_peak_var  \
# 0      0            0.142377        0.051575            0.027725
# 1      1            0.141898        0.056554            0.033343
#
#    price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# 0           42.903794        9.272559            5.982435
# 1           43.163536       11.192617            7.156747

# %%
grouped_test2=df_gptest[['churn', 'price_mid_peak_var']].groupby(['churn'])
grouped_test2.head(2)
# Out:
#     churn  price_mid_peak_var
# 0       1            0.071536
# 1       1            0.071536
# 12      0            0.000000
# 13      0            0.000000

# %%
grouped_test2.get_group('1')['churn']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-417711a72693> in <cell line: 1>()
# ----> 1 grouped_test2.get_group('1')['churn']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in get_group(self, name, obj)
#     815         inds = self._get_index(name)
#     816         if not len(inds):
# --> 817             raise KeyError(name)
#     818
#     819         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: '1'

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('1')['churn'], grouped_test2.get_group('0')['churn'])

print( "ANOVA results: F=", f_val, ", P =", p_val)

# %% [markdown]
# After carefully studying the dataset, I think the alternative model is true, thus, "**churning is not price sensitive"**

# %% [markdown]
# #model

# %%
#hot encoding some columns
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
#encoding channel sales
datale = New_data
datale.channel_sales = le.fit_transform(datale.channel_sales)
datale
# Out:
#                                       id  channel_sales  cons_12m  \
# 0       24011ae4ebbe3035111d65fa7c15bc57              4         0
# 1       24011ae4ebbe3035111d65fa7c15bc57              4         0
# 2       24011ae4ebbe3035111d65fa7c15bc57              4         0
# 3       24011ae4ebbe3035111d65fa7c15bc57              4         0
# 4       24011ae4ebbe3035111d65fa7c15bc57              4         0
# ...                                  ...            ...       ...
# 175144  563dde550fd624d7352f3de77c0cdfcd              0      8730
# 175145  563dde550fd624d7352f3de77c0cdfcd              0      8730
# 175146  563dde550fd624d7352f3de77c0cdfcd              0      8730
# 175147  563dde550fd624d7352f3de77c0cdfcd              0      8730
# 175148  563dde550fd624d7352f3de77c0cdfcd              0      8730
#
#         cons_gas_12m  cons_last_month  date_activ    date_end date_modif_prod  \
# 0              54946                0  2013-06-15  2016-06-15      2015-11-01
# ...

# %%
#encoding the has gas column
datale = New_data
datale.has_gas = le.fit_transform(datale.has_gas)
datale
# Out:
#                                       id  channel_sales  cons_12m  \
# 0       24011ae4ebbe3035111d65fa7c15bc57              4         0
# 1       24011ae4ebbe3035111d65fa7c15bc57              4         0
# 2       24011ae4ebbe3035111d65fa7c15bc57              4         0
# 3       24011ae4ebbe3035111d65fa7c15bc57              4         0
# 4       24011ae4ebbe3035111d65fa7c15bc57              4         0
# ...                                  ...            ...       ...
# 175144  563dde550fd624d7352f3de77c0cdfcd              0      8730
# 175145  563dde550fd624d7352f3de77c0cdfcd              0      8730
# 175146  563dde550fd624d7352f3de77c0cdfcd              0      8730
# 175147  563dde550fd624d7352f3de77c0cdfcd              0      8730
# 175148  563dde550fd624d7352f3de77c0cdfcd              0      8730
#
#         cons_gas_12m  cons_last_month  date_activ    date_end date_modif_prod  \
# 0              54946                0  2013-06-15  2016-06-15      2015-11-01
# ...

# %%
#changing the data type of the encoded columns
datale['channel_sales'] = datale['channel_sales'].astype('int')
datale['has_gas'] = datale['has_gas'].astype('int')
New_data.head()
# Out:
#                                  id  channel_sales  cons_12m  cons_gas_12m  \
# 0  24011ae4ebbe3035111d65fa7c15bc57              4         0         54946
# 1  24011ae4ebbe3035111d65fa7c15bc57              4         0         54946
# 2  24011ae4ebbe3035111d65fa7c15bc57              4         0         54946
# 3  24011ae4ebbe3035111d65fa7c15bc57              4         0         54946
# 4  24011ae4ebbe3035111d65fa7c15bc57              4         0         54946
#
#    cons_last_month  date_activ    date_end date_modif_prod date_renewal  \
# 0                0  2013-06-15  2016-06-15      2015-11-01   2015-06-23
# 1                0  2013-06-15  2016-06-15      2015-11-01   2015-06-23
# 2                0  2013-06-15  2016-06-15      2015-11-01   2015-06-23
# 3                0  2013-06-15  2016-06-15      2015-11-01   2015-06-23
# 4                0  2013-06-15  2016-06-15      2015-11-01   2015-06-23
#
#    forecast_cons_12m  ...                         origin_up  pow_max  churn  \
# ...

# %%
#Now checking correlation again
dfcor=New_data.corr()
dfcor
# Out:
# <ipython-input-63-16e4d4ecf51b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfcor=New_data.corr()
#                                 channel_sales  cons_12m  cons_gas_12m  \
# channel_sales                        1.000000  0.065505      0.006471
# cons_12m                             0.065505  1.000000      0.488253
# cons_gas_12m                         0.006471  0.488253      1.000000
# cons_last_month                      0.054536  0.968209      0.506883
# forecast_cons_12m                    0.021394  0.194080      0.084520
# forecast_cons_year                  -0.005147  0.167141      0.081010
# forecast_discount_energy             0.037053 -0.043291     -0.012581
# forecast_meter_rent_12m             -0.027701  0.065275      0.041314
# ...

# %%
sns.heatmap(dfcor)
plt.show()

# %%
X = np.asarray(datale[['forecast_meter_rent_12m','net_margin','price_mid_peak_var','price_peak_fix','price_mid_peak_fix']])
X[0:5]
# Out:
# array([[1.78000000e+00, 6.78990000e+02, 7.15360000e-02, 2.43395807e+01,
#         1.62263887e+01],
#        [1.78000000e+00, 6.78990000e+02, 7.15360000e-02, 2.43395807e+01,
#         1.62263887e+01],
#        [1.78000000e+00, 6.78990000e+02, 7.15360000e-02, 2.43395780e+01,
#         1.62263830e+01],
#        [1.78000000e+00, 6.78990000e+02, 7.15360000e-02, 2.43395780e+01,
#         1.62263830e+01],
#        [1.78000000e+00, 6.78990000e+02, 7.15360000e-02, 2.43395780e+01,
#         1.62263830e+01]])

# %%
y = np.asarray(New_data['churn'])
y [0:5]
# Out:
# array([1, 1, 1, 1, 1])

# %% [markdown]
# # USING RANDOM FOREST

# %%
#importing a standard scaler for the values of X
from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
# Out:
# array([[-0.92668765,  1.57047034,  1.19965607,  1.22644213,  1.2950217 ],
#        [-0.92668765,  1.57047034,  1.19965607,  1.22644213,  1.2950217 ],
#        [-0.92668765,  1.57047034,  1.19965607,  1.22644191,  1.29502097],
#        [-0.92668765,  1.57047034,  1.19965607,  1.22644191,  1.29502097],
#        [-0.92668765,  1.57047034,  1.19965607,  1.22644191,  1.29502097]])

# %%
#splitting the dataset into test and train
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
#import the model
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10,random_state=42,n_jobs=-1,oob_score=True)
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:583: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# RandomForestClassifier(n_estimators=10, n_jobs=-1, oob_score=True,
#                        random_state=42)

# %%
#getting the score of the model
model.score(X_test,y_test)
# Out:
# 0.9962888952326577

# %%
from sklearn.metrics import classification_report, confusion_matrix
pred=model.predict(X_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
cm2=confusion_matrix(y_test,pred)
cm2
# Out:
# array([[31563,    16],
#        [  114,  3337]])

# %%
sns.heatmap(cm2,annot=True)
plt.show()

# %%
from imblearn.over_sampling import RandomOverSampler
ros= RandomOverSampler(random_state=0)
X_train_resampled,y_train_resampled= ros.fit_resample(X_train,y_train)

# %%
model = RandomForestClassifier(n_estimators=10,random_state=42,n_jobs=-1,oob_score=True)
model.fit(X_train_resampled, y_train_resampled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:583: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# RandomForestClassifier(n_estimators=10, n_jobs=-1, oob_score=True,
#                        random_state=42)

# %%
model.score(X_test,y_test)
# Out:
# 0.9967741935483871

# %%
pred=model.predict(X_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
cm2=confusion_matrix(y_test,pred)
cm2
# Out:
# array([[31541,    38],
#        [   75,  3376]])

# %%
sns.heatmap(cm2,annot=True)
plt.show()

# %%
print (classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     31579
#            1       0.99      0.98      0.98      3451
#
#     accuracy                           1.00     35030
#    macro avg       0.99      0.99      0.99     35030
# weighted avg       1.00      1.00      1.00     35030

# %% [markdown]
# The random forest is the best classifier for the model

# %% [markdown]
# One of the drawbacks of learning with a single tree is the problem of overfitting. Single trees tend to learn the training data too well, resulting in poor prediction performance on unseen data.

# %% [markdown]
# The Prediction is better when smote was used

# %% [markdown]
# # USING LOGISTIC REGRESSION

# %% [markdown]
# The variables of X are obtained from values that have a correlation with Churn

# %% [markdown]
# The variable of y is dependent on X

# %%
#splitting data into test train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=2)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (122604, 5) (122604,)
# Test set: (52545, 5) (52545,)

# %%
#Importing the logistic regressing model and training the dataset
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression().fit(X_train,y_train)
LR
# Out:
# LogisticRegression()

# %%
#predicting the model
yhat = LR.predict(X_test)
yhat
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
yhat_prob = LR.predict_proba(X_test)
yhat_prob
# Out:
# array([[0.91576817, 0.08423183],
#        [0.91558892, 0.08441108],
#        [0.91378375, 0.08621625],
#        ...,
#        [0.91317833, 0.08682167],
#        [0.88486081, 0.11513919],
#        [0.88815348, 0.11184652]])

# %%
from sklearn.metrics import jaccard_score
jaccard_score(y_test, yhat,pos_label=0)
# Out:
# 0.9027254386966617

# %%
from sklearn.metrics import classification_report, confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
print(confusion_matrix(y_test, yhat, labels=[1,0]))
# Out:
# [[    3  5108]
#  [    3 47431]]

# %%
cnf_matrix = confusion_matrix(y_test, yhat, labels=[1,0])
np.set_printoptions(precision=2)


# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['churn=1','churn=0'],normalize= False,  title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[    3  5108]
#  [    3 47431]]

# %%
print (classification_report(y_test, yhat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     47434
#            1       0.50      0.00      0.00      5111
#
#     accuracy                           0.90     52545
#    macro avg       0.70      0.50      0.48     52545
# weighted avg       0.86      0.90      0.86     52545

# %% [markdown]
# ## USING SMOTE TO FIX THE IMBALANCE

# %%
# !pip install imbalanced-learn

# %%
import imblearn
print(imblearn.__version__)
# Out:
# 0.10.1

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=27)
smote_X_train,smote_y_train=smote.fit_resample(X_train,y_train)

# %%
print(y_train.shape)
print(smote_y_train.shape)
# Out:
# (122604,)
# (221424,)

# %%
LR = LogisticRegression().fit(smote_X_train,smote_y_train)
LR
# Out:
# LogisticRegression()

# %%
yhat = LR.predict(X_test)
yhat
# Out:
# array([0, 0, 0, ..., 0, 1, 1])

# %%
yhat_prob = LR.predict_proba(X_test)
yhat_prob
# Out:
# array([[0.54, 0.46],
#        [0.54, 0.46],
#        [0.53, 0.47],
#        ...,
#        [0.53, 0.47],
#        [0.45, 0.55],
#        [0.46, 0.54]])

# %%
jaccard_score(y_test, yhat,pos_label=0)
# Out:
# 0.5840417272202425

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
print(confusion_matrix(y_test, yhat, labels=[1,0]))
# Out:
# [[ 2314  2797]
#  [18097 29337]]

# %%
cnf_matrix = confusion_matrix(y_test, yhat, labels=[1,0])
np.set_printoptions(precision=2)


# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['churn=1','churn=0'],normalize= False,  title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[ 2314  2797]
#  [18097 29337]]

# %%
print (classification_report(y_test, yhat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.62      0.74     47434
#            1       0.11      0.45      0.18      5111
#
#     accuracy                           0.60     52545
#    macro avg       0.51      0.54      0.46     52545
# weighted avg       0.84      0.60      0.68     52545

# %% [markdown]
# ## USING THE RANDOM OVERSAMPLER

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=2)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (122604, 5) (122604,)
# Test set: (52545, 5) (52545,)

# %%
from imblearn.over_sampling import RandomOverSampler
ros= RandomOverSampler(random_state=0)
X_train_resampled,y_train_resampled= ros.fit_resample(X_train,y_train)

# %%
LR = LogisticRegression().fit(X_train_resampled,y_train_resampled)
LR
# Out:
# LogisticRegression()

# %%
yhat = LR.predict(X_test)
yhat
# Out:
# array([0, 0, 0, ..., 0, 1, 1])

# %%
yhat_prob = LR.predict_proba(X_test)
yhat_prob
# Out:
# array([[0.54, 0.46],
#        [0.54, 0.46],
#        [0.53, 0.47],
#        ...,
#        [0.53, 0.47],
#        [0.45, 0.55],
#        [0.46, 0.54]])

# %%
jaccard_score(y_test, yhat,pos_label=0)
# Out:
# 0.5836817584517979

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
print(confusion_matrix(y_test, yhat, labels=[1,0]))
# Out:
# [[ 2319  2792]
#  [18118 29316]]

# %%
cnf_matrix = confusion_matrix(y_test, yhat, labels=[1,0])
np.set_printoptions(precision=2)


# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['churn=1','churn=0'],normalize= False,  title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[ 2319  2792]
#  [18118 29316]]

# %%
X = np.asarray(datale[['forecast_meter_rent_12m','net_margin','price_mid_peak_var','price_peak_fix','price_mid_peak_fix']])
X[0:5]
# Out:
# array([[1.78e+00, 6.79e+02, 7.15e-02, 2.43e+01, 1.62e+01],
#        [1.78e+00, 6.79e+02, 7.15e-02, 2.43e+01, 1.62e+01],
#        [1.78e+00, 6.79e+02, 7.15e-02, 2.43e+01, 1.62e+01],
#        [1.78e+00, 6.79e+02, 7.15e-02, 2.43e+01, 1.62e+01],
#        [1.78e+00, 6.79e+02, 7.15e-02, 2.43e+01, 1.62e+01]])

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
x = lambda a, b : a * b
print(x(5, 6))
# Out:
# 30

# %%
arr = np.arange(1, 11)
b = np.logical_and(arr <= 5, arr >= 8)
print(arr[b])
# Out:
# []
